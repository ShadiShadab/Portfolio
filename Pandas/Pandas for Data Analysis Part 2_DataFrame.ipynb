# %% [markdown]
# # Pandas for Data Analysis Part 2 PANDAS DATAFRAME

# %%
# Pandas is a data manipulation and analysis tool that is built on Numpy.
# Pandas uses a data structure known as DataFrame (think of it as Microsoft excel in Python). 
# DataFrames empower programmers to store and manipulate data in a tabular fashion (rows and columns).
# Series Vs. DataFrame? Series is considered a single column of a DataFrame.
import pandas as pd
import numpy as np

# %%
# Let's define a two-dimensional Pandas DataFrame
# Note that you can create a pandas dataframe from a python dictionary
employee_dataf = pd.DataFrame( {"Employee ID" : [1, 2, 3, 4], "Employee Name" : ["Laila Ali", "Shadi Shadab", "Sara Jackson", "Jack James"], 
                           "Annual Salary[$]" : [35000, 40000, 100000, 25000], "Years with Company" : [5, 7, 10, 1]})
employee_dataf
# Out:
#    Employee ID Employee Name  Annual Salary[$]  Years with Company
# 0            1     Laila Ali             35000                   5
# 1            2  Shadi Shadab             40000                   7
# 2            3  Sara Jackson            100000                  10
# 3            4    Jack James             25000                   1

# %%
# Let's obtain the data type 
type(employee_dataf)
# Out:
# pandas.core.frame.DataFrame

# %%
# you can only view the first couple of rows using .head()
employee_dataf.head(3)
# Out:
#    Employee ID Employee Name  Annual Salary[$]  Years with Company
# 0            1     Laila Ali             35000                   5
# 1            2  Shadi Shadab             40000                   7
# 2            3  Sara Jackson            100000                  10

# %%
# you can only view the last couple of rows using .tail()
employee_dataf.tail(2)
# Out:
#    Employee ID Employee Name  Annual Salary[$]  Years with Company
# 2            3  Sara Jackson            100000                  10
# 3            4    Jack James             25000                   1

# %%
# Obtain DataFrame information 
employee_dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee ID         4 non-null      int64
#  1   Employee Name       4 non-null      object
#  2   Annual Salary[$]    4 non-null      int64
#  3   Years with Company  4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 256.0+ bytes

# %%
portfolio_df = pd.DataFrame({"Symbol" : ["$", "&", "#"],
                             "Number of shares" : [100, 123, 56], 
                             "Price per share" : [32, 60, 17] })
portfolio_df
# Out:
#   Symbol  Number of shares  Price per share
# 0      $               100               32
# 1      &               123               60
# 2      #                56               17

# %%
total_value = portfolio_df["Price per share"] * portfolio_df["Number of shares"]
total_value
# Out:
# 0    3200
# 1    7380
# 2     952
# dtype: int64

# %%
total_value.sum()
# Out:
# 11532

# %%
house_prices_df = pd.read_html("https://www.livingin-canada.com/house-prices-canada.html")

# %%
# Read tabular data using read_html
house_prices_df[0]
# Out:
#                                                 City  \
# 0                                      Vancouver, BC
# 1                                       Toronto, Ont
# 2                                        Ottawa, Ont
# 3                                       Calgary, Alb
# 4                                      Montreal, Que
# 5                                        Halifax, NS
# 6                                       Regina, Sask
# 7                                    Fredericton, NB
# 8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                  Average House Price  \
# 0                                         $1,036,000
# 1                                           $870,000
# 2                                           $479,000
# 3                                           $410,000
# 4                                           $435,000
# 5                                           $331,000
# 6                                           $254,000
# 7                                           $198,000
# 8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                      12 Month Change
# 0                                           + 2.63 %
# 1                                            +10.2 %
# 2                                           + 15.4 %
# 3                                            – 1.5 %
# 4                                            + 9.3 %
# 5                                            + 3.6 %
# 6                                            – 3.9 %
# 7                                            – 4.3 %
# 8  (adsbygoogle = window.adsbygoogle || []).push(...

# %%
house_prices_df[1]
# Out:
#                                              Province  \
# 0                                    British Columbia
# 1                                             Ontario
# 2                                             Alberta
# 3                                              Quebec
# 4                                            Manitoba
# 5                                        Saskatchewan
# 6                                         Nova Scotia
# 7                                Prince Edward Island
# 8                             Newfoundland / Labrador
# 9                                       New Brunswick
# 10                                   Canadian Average
# 11  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                   Average House Price  \
# 0                                            $736,000
# 1                                            $594,000
# 2                                            $353,000
# 3                                            $340,000
# 4                                            $295,000
# 5                                            $271,000
# 6                                            $266,000
# 7                                            $243,000
# 8                                            $236,000
# 9                                            $183,000
# 10                                           $488,000
# 11  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                       12 Month Change
# 0                                             + 7.6 %
# 1                                             – 3.2 %
# 2                                             – 7.5 %
# 3                                             + 7.6 %
# 4                                             – 1.4 %
# 5                                             – 3.8 %
# 6                                             + 3.5 %
# 7                                             + 3.0 %
# 8                                             – 1.6 %
# 9                                             – 2.2 %
# 10                                            – 1.3 %
# 11  (adsbygoogle = window.adsbygoogle || []).push(...

# %%
employee_dataframe = pd.DataFrame({'Employee ID':[1, 2, 3, 4], 
                            'Employee Name':['Laila Aly', 'Kate Steve', 'Nicole Mitch', 'Francis Morris'], 
                            'Annual Salary [$]':[35000, 40000, 100000, 25000], 
                            'Years with Company':[5, 7, 10, 1]})
employee_dataframe
# Out:
#    Employee ID   Employee Name  Annual Salary [$]  Years with Company
# 0            1       Laila Aly              35000                   5
# 1            2      Kate Steve              40000                   7
# 2            3    Nicole Mitch             100000                  10
# 3            4  Francis Morris              25000                   1

# %%
#WRITE DATAFRAME INTO CSV
# write to a csv file without an index
employee_dataframe.to_csv("employee1_info.csv", index = True)

# %%
employee_dataframe.to_csv("employee1_info.csv", index = False)

# %%
# Pandas is used to read a csv file and store data in a DataFrame
# Note that a numeric index is being set by default
employee_df = pd.read_csv("Pandas for Data Analysis Part 2_DataFrame.csv")
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
# You can assign a specific column to be the index as follows
employee_df.set_index("First Name", inplace = True)
employee_df
# Out:
#            Last Name     Salary  Years with Company Postal Code  \
# First Name
# Mike             Moe    5000.00                   3     N94 3M0
# Noah            Ryan   10000.00                   8     N8S 14K
# Nina          Keller    9072.02                  17     S1T 4E6
# Chanel         Steve   11072.02                  12     N7T 3E6
# Kate            Noor    5000.00                  23     K8N 5H6
# Samer             Mo  100000.00                  13     J7H 3HY
# Heba          Ismail   50000.00                   7     K8Y 3M8
# Laila            Aly   20000.00                   5     J8Y 3M0
# Joseph        Patton    2629.13                   2     M6U 5U7
# Noah           Moran    8626.96                  11     K2D 4M9
#
#                               Email
# First Name
# Mike                 bird@gmail.com
# Noah             nsmall@hotmail.com
# Nina                azikez@gahew.mr
# Chanel             chanel@gmail.com
# Kate               kate@hotmail.com
# Samer               samer@gmail.com
# Heba        heba.ismail@hotmail.com
# Laila           Laila.a@hotmail.com
# Joseph               daafeja@boh.jm
# Noah              guutodi@bigwoc.kw

# %%
# You can go back and use numeric index using reset_index
employee_df.reset_index(inplace = True)
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
# Alternatively, you can set the index name when you read the csv file as follows
employee_df = pd.read_csv("Pandas for Data Analysis Part 2_DataFrame.csv", index_col = "First Name")
employee_df
# Out:
#            Last Name     Salary  Years with Company Postal Code  \
# First Name
# Mike             Moe    5000.00                   3     N94 3M0
# Noah            Ryan   10000.00                   8     N8S 14K
# Nina          Keller    9072.02                  17     S1T 4E6
# Chanel         Steve   11072.02                  12     N7T 3E6
# Kate            Noor    5000.00                  23     K8N 5H6
# Samer             Mo  100000.00                  13     J7H 3HY
# Heba          Ismail   50000.00                   7     K8Y 3M8
# Laila            Aly   20000.00                   5     J8Y 3M0
# Joseph        Patton    2629.13                   2     M6U 5U7
# Noah           Moran    8626.96                  11     K2D 4M9
#
#                               Email
# First Name
# Mike                 bird@gmail.com
# Noah             nsmall@hotmail.com
# Nina                azikez@gahew.mr
# Chanel             chanel@gmail.com
# Kate               kate@hotmail.com
# Samer               samer@gmail.com
# Heba        heba.ismail@hotmail.com
# Laila           Laila.a@hotmail.com
# Joseph               daafeja@boh.jm
# Noah              guutodi@bigwoc.kw

# %%
# Return a column from the DataFrame
# Note that the output will be a Pandas Series (you can automatically tell by the lack of formating)
sample = employee_df["Email"]
sample
# Out:
# First Name
# Mike                bird@gmail.com
# Noah            nsmall@hotmail.com
# Nina               azikez@gahew.mr
# Chanel            chanel@gmail.com
# Kate              kate@hotmail.com
# Samer              samer@gmail.com
# Heba       heba.ismail@hotmail.com
# Laila          Laila.a@hotmail.com
# Joseph              daafeja@boh.jm
# Noah             guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
# Confirm the datatype of sample
type(sample)
# Out:
# pandas.core.series.Series

# %%
# Alternatively, you can use the following syntax to do the same
# Note that this method will not work if there are spaces in the column names
employee_df.Email
# Out:
# First Name
# Mike                bird@gmail.com
# Noah            nsmall@hotmail.com
# Nina               azikez@gahew.mr
# Chanel            chanel@gmail.com
# Kate              kate@hotmail.com
# Samer              samer@gmail.com
# Heba       heba.ismail@hotmail.com
# Laila          Laila.a@hotmail.com
# Joseph              daafeja@boh.jm
# Noah             guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
# Since the column name has spaces, this will be the only way that will work!
employee_df["Years with Company"]
# Out:
# First Name
# Mike        3
# Noah        8
# Nina       17
# Chanel     12
# Kate       23
# Samer      13
# Heba        7
# Laila       5
# Joseph      2
# Noah       11
# Name: Years with Company, dtype: int64

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv("Pandas for Data Analysis Part 2_DataFrame.csv")
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
# Let's select multiple columns from the DataFrame
# you need to define a list containing all column names that you would like to select
# Note that since we collected more than one column, the output is a DataFrame (Notice the rich formatting)
sample = employee_df[["First Name", "Salary"]]
sample
# Out:
#   First Name     Salary
# 0       Mike    5000.00
# 1       Noah   10000.00
# 2       Nina    9072.02
# 3    Chanel    11072.02
# 4       Kate    5000.00
# 5      Samer  100000.00
# 6       Heba   50000.00
# 7      Laila   20000.00
# 8     Joseph    2629.13
# 9       Noah    8626.96

# %%
# Note that sample is now a DataFrame and not a Pandas Series (since it has multiple columns)
# You can use type to confirm or you can tell from the rich text formating
type(sample)
# Out:
# pandas.core.frame.DataFrame

# %%
# Alternatively, you can define a list first and then use it to select columns
my_selected_columns = ["First Name", "Salary" ]
sample = employee_df[my_selected_columns]
sample
# Out:
#   First Name     Salary
# 0       Mike    5000.00
# 1       Noah   10000.00
# 2       Nina    9072.02
# 3    Chanel    11072.02
# 4       Kate    5000.00
# 5      Samer  100000.00
# 6       Heba   50000.00
# 7      Laila   20000.00
# 8     Joseph    2629.13
# 9       Noah    8626.96

# %%
# In order to access a given row in the dataframe
employee_df[0:3]
# Out:
#   First Name Last Name    Salary  Years with Company Postal Code  \
# 0       Mike       Moe   5000.00                   3     N94 3M0
# 1       Noah      Ryan  10000.00                   8     N8S 14K
# 2       Nina    Keller   9072.02                  17     S1T 4E6
#
#                 Email
# 0      bird@gmail.com
# 1  nsmall@hotmail.com
# 2     azikez@gahew.mr

# %%
# Let's assume that we want to add a new column to the dataframe
employee_df["Age"] = [25, 26, 28, 30, 34, 22, 36, 55, 63, 26]
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email  Age
# 0           bird@gmail.com   25
# 1       nsmall@hotmail.com   26
# 2          azikez@gahew.mr   28
# 3         chanel@gmail.com   30
# 4         kate@hotmail.com   34
# 5          samer@gmail.com   22
# 6  heba.ismail@hotmail.com   36
# 7      Laila.a@hotmail.com   55
# 8           daafeja@boh.jm   63
# 9        guutodi@bigwoc.kw   26

# %%
# You can also insert a new column in a given position 
employee_df.insert(0, column = "Credit Score", value = [600, 700, 650, 720, 400, 830, 674, 780, 900, 810])
employee_df
# Out:
#    Credit Score First Name Last Name     Salary  Years with Company  \
# 0           600       Mike       Moe    5000.00                   3
# 1           700       Noah      Ryan   10000.00                   8
# 2           650       Nina    Keller    9072.02                  17
# 3           720    Chanel      Steve   11072.02                  12
# 4           400       Kate      Noor    5000.00                  23
# 5           830      Samer        Mo  100000.00                  13
# 6           674       Heba    Ismail   50000.00                   7
# 7           780      Laila       Aly   20000.00                   5
# 8           900     Joseph    Patton    2629.13                   2
# 9           810       Noah     Moran    8626.96                  11
#
#   Postal Code                    Email  Age
# 0     N94 3M0           bird@gmail.com   25
# 1     N8S 14K       nsmall@hotmail.com   26
# 2     S1T 4E6          azikez@gahew.mr   28
# 3     N7T 3E6         chanel@gmail.com   30
# 4     K8N 5H6         kate@hotmail.com   34
# 5     J7H 3HY          samer@gmail.com   22
# 6     K8Y 3M8  heba.ismail@hotmail.com   36
# 7     J8Y 3M0      Laila.a@hotmail.com   55
# 8     M6U 5U7           daafeja@boh.jm   63
# 9     K2D 4M9        guutodi@bigwoc.kw   26

# %%
# Delete a column from a DataFrame
del employee_df["Email"]
employee_df
# Out:
#    Credit Score First Name Last Name     Salary  Years with Company  \
# 0           600       Mike       Moe    5000.00                   3
# 1           700       Noah      Ryan   10000.00                   8
# 2           650       Nina    Keller    9072.02                  17
# 3           720    Chanel      Steve   11072.02                  12
# 4           400       Kate      Noor    5000.00                  23
# 5           830      Samer        Mo  100000.00                  13
# 6           674       Heba    Ismail   50000.00                   7
# 7           780      Laila       Aly   20000.00                   5
# 8           900     Joseph    Patton    2629.13                   2
# 9           810       Noah     Moran    8626.96                  11
#
#   Postal Code  Age
# 0     N94 3M0   25
# 1     N8S 14K   26
# 2     S1T 4E6   28
# 3     N7T 3E6   30
# 4     K8N 5H6   34
# 5     J7H 3HY   22
# 6     K8Y 3M8   36
# 7     J8Y 3M0   55
# 8     M6U 5U7   63
# 9     K2D 4M9   26

# %%
employee_df.drop(labels=["Last Name", "Salary"], axis = 1, inplace = True)
employee_df
# Out:
#    Credit Score First Name  Years with Company Postal Code  Age
# 0           600       Mike                   3     N94 3M0   25
# 1           700       Noah                   8     N8S 14K   26
# 2           650       Nina                  17     S1T 4E6   28
# 3           720    Chanel                   12     N7T 3E6   30
# 4           400       Kate                  23     K8N 5H6   34
# 5           830      Samer                  13     J7H 3HY   22
# 6           674       Heba                   7     K8Y 3M8   36
# 7           780      Laila                   5     J8Y 3M0   55
# 8           900     Joseph                   2     M6U 5U7   63
# 9           810       Noah                  11     K2D 4M9   26

# %%
# Remove a column from a DataFrame and store it somehwere else using pop
years_with_company = employee_df.pop("Years with Company")
years_with_company
# Out:
# 0     3
# 1     8
# 2    17
# 3    12
# 4    23
# 5    13
# 6     7
# 7     5
# 8     2
# 9    11
# Name: Years with Company, dtype: int64

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv("Pandas for Data Analysis Part 2_DataFrame.csv", index_col = "Last Name")
employee_df
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Moe             Mike    5000.00                   3     N94 3M0
# Ryan            Noah   10000.00                   8     N8S 14K
# Keller          Nina    9072.02                  17     S1T 4E6
# Steve        Chanel    11072.02                  12     N7T 3E6
# Noor            Kate    5000.00                  23     K8N 5H6
# Mo             Samer  100000.00                  13     J7H 3HY
# Ismail          Heba   50000.00                   7     K8Y 3M8
# Aly            Laila   20000.00                   5     J8Y 3M0
# Patton        Joseph    2629.13                   2     M6U 5U7
# Moran           Noah    8626.96                  11     K2D 4M9
#
#                              Email
# Last Name
# Moe                 bird@gmail.com
# Ryan            nsmall@hotmail.com
# Keller             azikez@gahew.mr
# Steve             chanel@gmail.com
# Noor              kate@hotmail.com
# Mo                 samer@gmail.com
# Ismail     heba.ismail@hotmail.com
# Aly            Laila.a@hotmail.com
# Patton              daafeja@boh.jm
# Moran            guutodi@bigwoc.kw

# %%
# Sort the dataframe in an alphabetical order
employee_df.sort_index(inplace = True)

# %%
# loc is used to filter rows and columns
# loc is label-based meaning you need to give a name of the rows (or columns) that you are interested in selecting
# Note that iloc is "integer index-based" meaning you can filter rows/columns by their integer index.
# Note that we obtained a Series because last name "Aly" existed only once in the dataframe
employee_df.loc["Aly"]
# Out:
# First Name                          Laila
# Salary                            20000.0
# Years with Company                      5
# Postal Code                       J8Y 3M0
# Email                 Laila.a@hotmail.com
# Name: Aly, dtype: object

# %%
# Note that you can select multiple rows using "colon :"
# Note that this is inclusive! meaning that "Aly" and "Patton" were selected in the output DataFrame
# Headsup: this will be different if we use integer based index such as iloc()
employee_df.loc['Aly':'Patton']
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila   20000.00                   5     J8Y 3M0
# Ismail          Heba   50000.00                   7     K8Y 3M8
# Keller          Nina    9072.02                  17     S1T 4E6
# Mo             Samer  100000.00                  13     J7H 3HY
# Moe             Mike    5000.00                   3     N94 3M0
# Moran           Noah    8626.96                  11     K2D 4M9
# Noor            Kate    5000.00                  23     K8N 5H6
# Patton        Joseph    2629.13                   2     M6U 5U7
#
#                              Email
# Last Name
# Aly            Laila.a@hotmail.com
# Ismail     heba.ismail@hotmail.com
# Keller             azikez@gahew.mr
# Mo                 samer@gmail.com
# Moe                 bird@gmail.com
# Moran            guutodi@bigwoc.kw
# Noor              kate@hotmail.com
# Patton              daafeja@boh.jm

# %%
# Select all elements up to and including 'Keller' index
employee_df.loc[:'Keller']
# Out:
#           First Name    Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila  20000.00                   5     J8Y 3M0
# Ismail          Heba  50000.00                   7     K8Y 3M8
# Keller          Nina   9072.02                  17     S1T 4E6
#
#                              Email
# Last Name
# Aly            Laila.a@hotmail.com
# Ismail     heba.ismail@hotmail.com
# Keller             azikez@gahew.mr

# %%
# if you want to select multiple rows, you can pass them as a list as follows
employee_df.loc[['Keller', 'Steve', 'Mo']]
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Keller          Nina    9072.02                  17     S1T 4E6
# Steve        Chanel    11072.02                  12     N7T 3E6
# Mo             Samer  100000.00                  13     J7H 3HY
#
#                       Email
# Last Name
# Keller      azikez@gahew.mr
# Steve      chanel@gmail.com
# Mo          samer@gmail.com

# %%
# You can also randomly select a fraction of the DataFrame
# Setting axis = 0 means rows, setting index = 1 means columns
employee_df.sample(n=5, axis = 0)
# Out:
#           First Name    Salary  Years with Company Postal Code  \
# Last Name
# Noor            Kate   5000.00                  23     K8N 5H6
# Ryan            Noah  10000.00                   8     N8S 14K
# Patton        Joseph   2629.13                   2     M6U 5U7
# Moran           Noah   8626.96                  11     K2D 4M9
# Ismail          Heba  50000.00                   7     K8Y 3M8
#
#                              Email
# Last Name
# Noor              kate@hotmail.com
# Ryan            nsmall@hotmail.com
# Patton              daafeja@boh.jm
# Moran            guutodi@bigwoc.kw
# Ismail     heba.ismail@hotmail.com

# %%
# return a percentage (Ex: 30%) of the rows 
employee_df.sample(frac= 0.3, axis = 0)
# Out:
#           First Name    Salary  Years with Company Postal Code  \
# Last Name
# Ismail          Heba   50000.0                   7     K8Y 3M8
# Aly            Laila   20000.0                   5     J8Y 3M0
# Mo             Samer  100000.0                  13     J7H 3HY
#
#                              Email
# Last Name
# Ismail     heba.ismail@hotmail.com
# Aly            Laila.a@hotmail.com
# Mo                 samer@gmail.com

# %%
# You can access rows with their numeric index using iloc
employee_df.iloc[9]
# Out:
# First Name                     Chanel
# Salary                        11072.02
# Years with Company                  12
# Postal Code                    N7T 3E6
# Email                 chanel@gmail.com
# Name: Steve, dtype: object

# %%
# You can access multiple rows with their numeric index using iloc and colon :
# Note that using iloc is exclusive, meaning that we did not include the last element.
# We went from index = 2 up until and not including index 5 so index 2,3, and 4 are the one selected
employee_df.iloc[2:5]
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Keller          Nina    9072.02                  17     S1T 4E6
# Mo             Samer  100000.00                  13     J7H 3HY
# Moe             Mike    5000.00                   3     N94 3M0
#
#                      Email
# Last Name
# Keller     azikez@gahew.mr
# Mo         samer@gmail.com
# Moe         bird@gmail.com

# %%
# all up until and not including index 4
employee_df.iloc[:4]
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila   20000.00                   5     J8Y 3M0
# Ismail          Heba   50000.00                   7     K8Y 3M8
# Keller          Nina    9072.02                  17     S1T 4E6
# Mo             Samer  100000.00                  13     J7H 3HY
#
#                              Email
# Last Name
# Aly            Laila.a@hotmail.com
# Ismail     heba.ismail@hotmail.com
# Keller             azikez@gahew.mr
# Mo                 samer@gmail.com

# %%
# Multiple elements are selected using a list of indexes 
employee_df.iloc[[2, 4, 9]]
# Out:
#           First Name    Salary  Years with Company Postal Code  \
# Last Name
# Keller          Nina   9072.02                  17     S1T 4E6
# Moe             Mike   5000.00                   3     N94 3M0
# Steve        Chanel   11072.02                  12     N7T 3E6
#
#                       Email
# Last Name
# Keller      azikez@gahew.mr
# Moe          bird@gmail.com
# Steve      chanel@gmail.com

# %%
# Slicing a piece of the dataframe by selecting which row and column you would like to select
employee_df.iloc[4, 0:3]
# Out:
# First Name              Mike
# Salary                5000.0
# Years with Company         3
# Name: Moe, dtype: object

# %%
# Let's assume that we want to update the salaries of all our employees by $1000
employee_df['Salary'] = employee_df['Salary'] + 1000
employee_df
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila   21000.00                   5     J8Y 3M0
# Ismail          Heba   51000.00                   7     K8Y 3M8
# Keller          Nina   10072.02                  17     S1T 4E6
# Mo             Samer  101000.00                  13     J7H 3HY
# Moe             Mike    6000.00                   3     N94 3M0
# Moran           Noah    9626.96                  11     K2D 4M9
# Noor            Kate    6000.00                  23     K8N 5H6
# Patton        Joseph    3629.13                   2     M6U 5U7
# Ryan            Noah   11000.00                   8     N8S 14K
# Steve        Chanel    12072.02                  12     N7T 3E6
#
#                              Email
# Last Name
# Aly            Laila.a@hotmail.com
# Ismail     heba.ismail@hotmail.com
# Keller             azikez@gahew.mr
# Mo                 samer@gmail.com
# Moe                 bird@gmail.com
# Moran            guutodi@bigwoc.kw
# Noor              kate@hotmail.com
# Patton              daafeja@boh.jm
# Ryan            nsmall@hotmail.com
# Steve             chanel@gmail.com

# %%
# Alternatively, you can add or subtract as follows
employee_df['Salary'] = employee_df['Salary'].add(1000)
employee_df
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila   22000.00                   5     J8Y 3M0
# Ismail          Heba   52000.00                   7     K8Y 3M8
# Keller          Nina   11072.02                  17     S1T 4E6
# Mo             Samer  102000.00                  13     J7H 3HY
# Moe             Mike    7000.00                   3     N94 3M0
# Moran           Noah   10626.96                  11     K2D 4M9
# Noor            Kate    7000.00                  23     K8N 5H6
# Patton        Joseph    4629.13                   2     M6U 5U7
# Ryan            Noah   12000.00                   8     N8S 14K
# Steve        Chanel    13072.02                  12     N7T 3E6
#
#                              Email
# Last Name
# Aly            Laila.a@hotmail.com
# Ismail     heba.ismail@hotmail.com
# Keller             azikez@gahew.mr
# Mo                 samer@gmail.com
# Moe                 bird@gmail.com
# Moran            guutodi@bigwoc.kw
# Noor              kate@hotmail.com
# Patton              daafeja@boh.jm
# Ryan            nsmall@hotmail.com
# Steve             chanel@gmail.com

# %%
# Let's convert from USD to CAD using the exchange rate 1 USD = 1.3 CAD 
employee_df['Salary(CAD)'] = employee_df['Salary'].mul(1.3)
employee_df
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila   22000.00                   5     J8Y 3M0
# Ismail          Heba   52000.00                   7     K8Y 3M8
# Keller          Nina   11072.02                  17     S1T 4E6
# Mo             Samer  102000.00                  13     J7H 3HY
# Moe             Mike    7000.00                   3     N94 3M0
# Moran           Noah   10626.96                  11     K2D 4M9
# Noor            Kate    7000.00                  23     K8N 5H6
# Patton        Joseph    4629.13                   2     M6U 5U7
# Ryan            Noah   12000.00                   8     N8S 14K
# Steve        Chanel    13072.02                  12     N7T 3E6
#
#                              Email  Salary(CAD)
# Last Name
# Aly            Laila.a@hotmail.com    28600.000
# Ismail     heba.ismail@hotmail.com    67600.000
# Keller             azikez@gahew.mr    14393.626
# Mo                 samer@gmail.com   132600.000
# Moe                 bird@gmail.com     9100.000
# Moran            guutodi@bigwoc.kw    13815.048
# Noor              kate@hotmail.com     9100.000
# Patton              daafeja@boh.jm     6017.869
# Ryan            nsmall@hotmail.com    15600.000
# Steve             chanel@gmail.com    16993.626

# %%
# Decided to update the email address of a given customer
employee_df.iloc[4, 5] = 'kate.noor@gmail.com'
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    7000.00                   3     N94 3M0
# 1       Noah      Ryan   12000.00                   8     N8S 14K
# 2       Nina    Keller   11072.02                  17     S1T 4E6
# 3    Chanel      Steve   13072.02                  12     N7T 3E6
# 4       Kate      Noor    7000.00                  23     K8N 5H6
# 5      Samer        Mo  102000.00                  13     J7H 3HY
# 6       Heba    Ismail   52000.00                   7     K8Y 3M8
# 7      Laila       Aly   22000.00                   5     J8Y 3M0
# 8     Joseph    Patton    4629.13                   2     M6U 5U7
# 9       Noah     Moran   10626.96                  11     K2D 4M9
#
#                      Email  Salary(CAD)
# 0           bird@gmail.com     9100.000
# 1       nsmall@hotmail.com    15600.000
# 2          azikez@gahew.mr    14393.626
# 3         chanel@gmail.com    16993.626
# 4      kate.noor@gmail.com     9100.000
# 5          samer@gmail.com   132600.000
# 6  heba.ismail@hotmail.com    67600.000
# 7      Laila.a@hotmail.com    28600.000
# 8           daafeja@boh.jm     6017.869
# 9        guutodi@bigwoc.kw    13815.048

# %%
# You can sort the values in the dataframe according to number of years with bank
employee_df.sort_values(by = 'Years with Company')
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 8     Joseph    Patton    4629.13                   2     M6U 5U7
# 0       Mike       Moe    7000.00                   3     N94 3M0
# 7      Laila       Aly   22000.00                   5     J8Y 3M0
# 6       Heba    Ismail   52000.00                   7     K8Y 3M8
# 1       Noah      Ryan   12000.00                   8     N8S 14K
# 9       Noah     Moran   10626.96                  11     K2D 4M9
# 3    Chanel      Steve   13072.02                  12     N7T 3E6
# 5      Samer        Mo  102000.00                  13     J7H 3HY
# 2       Nina    Keller   11072.02                  17     S1T 4E6
# 4       Kate      Noor    7000.00                  23     K8N 5H6
#
#                      Email  Salary(CAD)
# 8           daafeja@boh.jm     6017.869
# 0           bird@gmail.com     9100.000
# 7      Laila.a@hotmail.com    28600.000
# 6  heba.ismail@hotmail.com    67600.000
# 1       nsmall@hotmail.com    15600.000
# 9        guutodi@bigwoc.kw    13815.048
# 3         chanel@gmail.com    16993.626
# 5          samer@gmail.com   132600.000
# 2          azikez@gahew.mr    14393.626
# 4      kate.noor@gmail.com     9100.000

# %%
# Note that nothing changed in memory! you have to make sure that inplace is set to True
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    7000.00                   3     N94 3M0
# 1       Noah      Ryan   12000.00                   8     N8S 14K
# 2       Nina    Keller   11072.02                  17     S1T 4E6
# 3    Chanel      Steve   13072.02                  12     N7T 3E6
# 4       Kate      Noor    7000.00                  23     K8N 5H6
# 5      Samer        Mo  102000.00                  13     J7H 3HY
# 6       Heba    Ismail   52000.00                   7     K8Y 3M8
# 7      Laila       Aly   22000.00                   5     J8Y 3M0
# 8     Joseph    Patton    4629.13                   2     M6U 5U7
# 9       Noah     Moran   10626.96                  11     K2D 4M9
#
#                      Email  Salary(CAD)
# 0           bird@gmail.com     9100.000
# 1       nsmall@hotmail.com    15600.000
# 2          azikez@gahew.mr    14393.626
# 3         chanel@gmail.com    16993.626
# 4      kate.noor@gmail.com     9100.000
# 5          samer@gmail.com   132600.000
# 6  heba.ismail@hotmail.com    67600.000
# 7      Laila.a@hotmail.com    28600.000
# 8           daafeja@boh.jm     6017.869
# 9        guutodi@bigwoc.kw    13815.048

# %%
# Set inplace = True to ensure that change has taken place in memory 
employee_df.sort_values(by = 'Years with Company', inplace = True)

# %%
# Note that now the change (ordering) took place 
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 8     Joseph    Patton    4629.13                   2     M6U 5U7
# 0       Mike       Moe    7000.00                   3     N94 3M0
# 7      Laila       Aly   22000.00                   5     J8Y 3M0
# 6       Heba    Ismail   52000.00                   7     K8Y 3M8
# 1       Noah      Ryan   12000.00                   8     N8S 14K
# 9       Noah     Moran   10626.96                  11     K2D 4M9
# 3    Chanel      Steve   13072.02                  12     N7T 3E6
# 5      Samer        Mo  102000.00                  13     J7H 3HY
# 2       Nina    Keller   11072.02                  17     S1T 4E6
# 4       Kate      Noor    7000.00                  23     K8N 5H6
#
#                      Email  Salary(CAD)
# 8           daafeja@boh.jm     6017.869
# 0           bird@gmail.com     9100.000
# 7      Laila.a@hotmail.com    28600.000
# 6  heba.ismail@hotmail.com    67600.000
# 1       nsmall@hotmail.com    15600.000
# 9        guutodi@bigwoc.kw    13815.048
# 3         chanel@gmail.com    16993.626
# 5          samer@gmail.com   132600.000
# 2          azikez@gahew.mr    14393.626
# 4      kate.noor@gmail.com     9100.000

# %%
# You can sort the values in a descending order as follows
employee_df.sort_values(by = 'Years with Company', ascending=False, inplace=True)
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 4       Kate      Noor    7000.00                  23     K8N 5H6
# 2       Nina    Keller   11072.02                  17     S1T 4E6
# 5      Samer        Mo  102000.00                  13     J7H 3HY
# 3    Chanel      Steve   13072.02                  12     N7T 3E6
# 9       Noah     Moran   10626.96                  11     K2D 4M9
# 1       Noah      Ryan   12000.00                   8     N8S 14K
# 6       Heba    Ismail   52000.00                   7     K8Y 3M8
# 7      Laila       Aly   22000.00                   5     J8Y 3M0
# 0       Mike       Moe    7000.00                   3     N94 3M0
# 8     Joseph    Patton    4629.13                   2     M6U 5U7
#
#                      Email  Salary(CAD)
# 4      kate.noor@gmail.com     9100.000
# 2          azikez@gahew.mr    14393.626
# 5          samer@gmail.com   132600.000
# 3         chanel@gmail.com    16993.626
# 9        guutodi@bigwoc.kw    13815.048
# 1       nsmall@hotmail.com    15600.000
# 6  heba.ismail@hotmail.com    67600.000
# 7      Laila.a@hotmail.com    28600.000
# 0           bird@gmail.com     9100.000
# 8           daafeja@boh.jm     6017.869

# %%
# You can sort the dataframe with index instead of values as follows
employee_df.sort_index(inplace = True)
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    7000.00                   3     N94 3M0
# 1       Noah      Ryan   12000.00                   8     N8S 14K
# 2       Nina    Keller   11072.02                  17     S1T 4E6
# 3    Chanel      Steve   13072.02                  12     N7T 3E6
# 4       Kate      Noor    7000.00                  23     K8N 5H6
# 5      Samer        Mo  102000.00                  13     J7H 3HY
# 6       Heba    Ismail   52000.00                   7     K8Y 3M8
# 7      Laila       Aly   22000.00                   5     J8Y 3M0
# 8     Joseph    Patton    4629.13                   2     M6U 5U7
# 9       Noah     Moran   10626.96                  11     K2D 4M9
#
#                      Email  Salary(CAD)
# 0           bird@gmail.com     9100.000
# 1       nsmall@hotmail.com    15600.000
# 2          azikez@gahew.mr    14393.626
# 3         chanel@gmail.com    16993.626
# 4      kate.noor@gmail.com     9100.000
# 5          samer@gmail.com   132600.000
# 6  heba.ismail@hotmail.com    67600.000
# 7      Laila.a@hotmail.com    28600.000
# 8           daafeja@boh.jm     6017.869
# 9        guutodi@bigwoc.kw    13815.048
